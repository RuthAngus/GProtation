# %% [markdown]
# # In this notebook I will experiment with fitting a function to the ACF in order to infer a rotation period.

# %%
import numpy as np
import matplotlib.pyplot as plt
from Kepler_ACF import corr_run
from simple_acf import simple_acf
# %matplotlib inline

# %% [markdown]
# Load data

# %%
x, y, yerr = np.genfromtxt("../simulations/noise-free/0000.txt").T
yerr = np.ones_like(x) * 1e-5
plt.plot(x, y, "k.")

# %%
period, period_err = corr_run(x, y, yerr, "test", ".", saveplot=False)
# Out:
# Calculating ACF...
# Calculating errors and asymmetries...
# no harmonic found or harmonic not 1st peak
# 10 Peaks kept
# >>>>>>>>>> [ 0.23498697  0.62322632  0.58235902 -0.03065048 -0.31672158 -0.09195143
#   0.52105807  0.03065048 -0.03065048 -0.07151778]
# 0.2424248236
# 0.0808082745333
# calculating var for P_med...
# PERIOD =  4.72017315 +/- 0.0808082745333
# saving as ./test_result.txt
# /Users/ruthangus/projects/GProtation/code/tests/Kepler_ACF.py:570: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 76 but corresponding boolean dimension is 18
#   delta_keep_pos = delta_keep_pos[ind_keep < ind_gap[0]]

# %%
lags, acf = np.genfromtxt("test_acf.txt").T
_, acf_smooth = np.genfromtxt("test_acf_smooth.txt").T
plt.plot(lags, acf)
plt.plot(lags, acf_smooth)
